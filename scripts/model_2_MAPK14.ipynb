# %%
#Import libraries
import pandas as pd
import numpy as np
from rdkit import Chem
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Normalization
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load dataset using pandas functionality
mapk14_data = pd.read_parquet('../data/mapk14_selected_data_model_2.parquet')


# Define variables for training to predict target enrichment for linear regression
y = mapk14_data['target_enrichment']

# Variables to drop
drop = ['target_enrichment']
X = mapk14_data.drop(drop, axis=1)
print(X.columns)
# Name the features
X_features = ['MaxAbsEStateIndex', 'MaxEStateIndex', 'MinAbsEStateIndex', 'MinEStateIndex', 'qed']

# Convert dataframes to numpy arrays for better computation
X = X.values
y = y.values

# Scale features
scaler_X = StandardScaler()
X_scaled = scaler_X.fit_transform(X)

scaler_y = StandardScaler()
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1))

# Train and test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)



# Set the seed for reproducibility
tf.random.set_seed(1234)

# Define the regression model
model = Sequential(
    [
        tf.keras.Input(shape=(5,)),  # Input shape matches the number of features
        Dense(50, activation="relu", name="layer1"),
        Dense(30, activation="relu", name="layer2"),
        Dense(1, activation="linear", name="output_layer"),  # Linear activation for regression
    ]
)

# Compile the model with a regression loss and optimizer
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),  # Optimizer
    loss="mean_squared_error",  # Loss function for regression
    metrics=["mean_absolute_error"],  # Additional metrics
)

# Model summary to verify structure
model.summary()


#Fit model to X
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    verbose=1,
)
# Out:
# Index(['MaxAbsEStateIndex', 'MaxEStateIndex', 'MinAbsEStateIndex',
#        'MinEStateIndex', 'qed'],
#       dtype='object')
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer1 (Dense)              (None, 50)                300
#
#  layer2 (Dense)              (None, 30)                1530
#
#  output_layer (Dense)        (None, 1)                 31
#
# =================================================================
# Total params: 1,861
# Trainable params: 1,861
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2024-11-27 18:03:40.553588: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 21875/21875 [==============================] - 6s 268us/step - loss: 0.0803 - mean_absolute_error: 0.1519
# Epoch 2/50
# 21875/21875 [==============================] - 6s 270us/step - loss: 0.0795 - mean_absolute_error: 0.1510
# Epoch 3/50
# 21875/21875 [==============================] - 6s 275us/step - loss: 0.0794 - mean_absolute_error: 0.1509
# Epoch 4/50
# 21875/21875 [==============================] - 6s 267us/step - loss: 0.0793 - mean_absolute_error: 0.1509
# Epoch 5/50
# 21875/21875 [==============================] - 6s 276us/step - loss: 0.0793 - mean_absolute_error: 0.1509
# Epoch 6/50
# 21875/21875 [==============================] - 6s 286us/step - loss: 0.0792 - mean_absolute_error: 0.1509
# Epoch 7/50
# 21875/21875 [==============================] - 6s 283us/step - loss: 0.0792 - mean_absolute_error: 0.1509
# Epoch 8/50
# 21875/21875 [==============================] - 6s 274us/step - loss: 0.0792 - mean_absolute_error: 0.1508
# Epoch 9/50
# 21875/21875 [==============================] - 6s 272us/step - loss: 0.0792 - mean_absolute_error: 0.1508
# Epoch 10/50
# 21875/21875 [==============================] - 6s 276us/step - loss: 0.0792 - mean_absolute_error: 0.1508
# Epoch 11/50
# 21875/21875 [==============================] - 6s 275us/step - loss: 0.0792 - mean_absolute_error: 0.1509
# Epoch 12/50
# 21875/21875 [==============================] - 6s 289us/step - loss: 0.0792 - mean_absolute_error: 0.1509
# Epoch 13/50
# 21875/21875 [==============================] - 6s 278us/step - loss: 0.0792 - mean_absolute_error: 0.1509
# Epoch 14/50
# 21875/21875 [==============================] - 6s 274us/step - loss: 0.0791 - mean_absolute_error: 0.1509
# Epoch 15/50
# 21875/21875 [==============================] - 6s 271us/step - loss: 0.0791 - mean_absolute_error: 0.1509
# Epoch 16/50
# 21875/21875 [==============================] - 6s 281us/step - loss: 0.0790 - mean_absolute_error: 0.1509
# Epoch 17/50
# 21875/21875 [==============================] - 6s 266us/step - loss: 0.0790 - mean_absolute_error: 0.1509
# Epoch 18/50
# 21875/21875 [==============================] - 6s 274us/step - loss: 0.0791 - mean_absolute_error: 0.1509
# Epoch 19/50
# 21875/21875 [==============================] - 6s 281us/step - loss: 0.0791 - mean_absolute_error: 0.1509
# Epoch 20/50
# 21875/21875 [==============================] - 6s 284us/step - loss: 0.0790 - mean_absolute_error: 0.1509
# Epoch 21/50
# 21875/21875 [==============================] - 6s 285us/step - loss: 0.0790 - mean_absolute_error: 0.1509
# Epoch 22/50
# 21875/21875 [==============================] - 6s 283us/step - loss: 0.0791 - mean_absolute_error: 0.1509
# Epoch 23/50
# 21875/21875 [==============================] - 6s 280us/step - loss: 0.0791 - mean_absolute_error: 0.1509
# Epoch 24/50
# 21875/21875 [==============================] - 6s 284us/step - loss: 0.0790 - mean_absolute_error: 0.1509
# Epoch 25/50
# 21875/21875 [==============================] - 6s 282us/step - loss: 0.0789 - mean_absolute_error: 0.1509
# Epoch 26/50
# 21875/21875 [==============================] - 6s 282us/step - loss: 0.0790 - mean_absolute_error: 0.1509
# Epoch 27/50
# 21875/21875 [==============================] - 6s 277us/step - loss: 0.0791 - mean_absolute_error: 0.1509
# Epoch 28/50
# 21875/21875 [==============================] - 6s 283us/step - loss: 0.0792 - mean_absolute_error: 0.1509
# Epoch 29/50
# 21875/21875 [==============================] - 6s 286us/step - loss: 0.0792 - mean_absolute_error: 0.1509
# Epoch 30/50
# 21875/21875 [==============================] - 6s 281us/step - loss: 0.0792 - mean_absolute_error: 0.1509
# Epoch 31/50
# 21875/21875 [==============================] - 6s 279us/step - loss: 0.0792 - mean_absolute_error: 0.1509
# Epoch 32/50
# 21875/21875 [==============================] - 6s 280us/step - loss: 0.0791 - mean_absolute_error: 0.1509
# Epoch 33/50
# 21875/21875 [==============================] - 6s 283us/step - loss: 0.0791 - mean_absolute_error: 0.1509
# Epoch 34/50
# 21875/21875 [==============================] - 6s 281us/step - loss: 0.0792 - mean_absolute_error: 0.1509
# Epoch 35/50
# 21875/21875 [==============================] - 6s 282us/step - loss: 0.0791 - mean_absolute_error: 0.1509
# Epoch 36/50
# 21875/21875 [==============================] - 6s 289us/step - loss: 0.0791 - mean_absolute_error: 0.1509
# Epoch 37/50
# 21875/21875 [==============================] - 6s 278us/step - loss: 0.0791 - mean_absolute_error: 0.1509
# Epoch 38/50
# 21875/21875 [==============================] - 6s 288us/step - loss: 0.0792 - mean_absolute_error: 0.1509
# Epoch 39/50
# 21875/21875 [==============================] - 6s 280us/step - loss: 0.0791 - mean_absolute_error: 0.1509
# Epoch 40/50
# 21875/21875 [==============================] - 6s 288us/step - loss: 0.0791 - mean_absolute_error: 0.1509
# Epoch 41/50
# 21875/21875 [==============================] - 6s 290us/step - loss: 0.0792 - mean_absolute_error: 0.1509
# Epoch 42/50
# 21875/21875 [==============================] - 6s 287us/step - loss: 0.0791 - mean_absolute_error: 0.1509
# Epoch 43/50
# 21875/21875 [==============================] - 6s 285us/step - loss: 0.0792 - mean_absolute_error: 0.1509
# Epoch 44/50
# 21875/21875 [==============================] - 6s 285us/step - loss: 0.0792 - mean_absolute_error: 0.1509
# Epoch 45/50
# 21875/21875 [==============================] - 6s 286us/step - loss: 0.0793 - mean_absolute_error: 0.1509
# Epoch 46/50
# 21875/21875 [==============================] - 6s 283us/step - loss: 0.0793 - mean_absolute_error: 0.1508
# Epoch 47/50
# 21875/21875 [==============================] - 6s 287us/step - loss: 0.0793 - mean_absolute_error: 0.1509
# Epoch 48/50
# 21875/21875 [==============================] - 6s 292us/step - loss: 0.0792 - mean_absolute_error: 0.1509
# Epoch 49/50
# 21875/21875 [==============================] - 6s 293us/step - loss: 0.0792 - mean_absolute_error: 0.1509
# Epoch 50/50
# 21875/21875 [==============================] - 6s 291us/step - loss: 0.0791 - mean_absolute_error: 0.1509

# %%
mapk14_data
# Out:
#         MaxAbsEStateIndex  MaxEStateIndex  MinAbsEStateIndex  MinEStateIndex  \
# 0               12.798375       12.798375           0.073516       -0.299840
# 1               13.027169       13.027169           0.054655       -1.009843
# 2               13.054667       13.054667           0.086620       -1.233746
# 3               12.958596       12.958596           0.037576       -1.035484
# 4               13.578384       13.578384           0.026380       -0.937045
# ...                   ...             ...                ...             ...
# 999995          12.290631       12.290631           0.053182       -0.870201
# 999996          13.997702       13.997702           0.034791       -1.307669
# 999997          12.946890       12.946890           0.208880       -1.124542
# 999998          12.877487       12.877487           0.034490       -0.549363
# 999999          13.428541       13.428541           0.041980       -0.950530
#
#              qed  target_enrichment
# 0       0.352533           0.321008
# 1       0.176153           0.367196
# 2       0.145309           0.440103
# 3       0.330833           0.440103
# 4       0.142115           0.337236
# ...          ...                ...
# 999995  0.365062           0.440103
# 999996  0.209236           0.321008
# 999997  0.188495           0.626325
# 999998  0.603143           0.505123
# 999999  0.235185           0.393946
#
# [1000000 rows x 6 columns]

# %%
# Evaluate the model
model.evaluate(X_test, y_test)


def plot_metrics(history, save_path):
    # Extract the metrics
    training_loss = history.history['loss']
    validation_loss = history.history.get('val_loss', None)
    training_mae = history.history['mean_absolute_error']
    validation_mae = history.history.get('val_mean_absolute_error', None)

    epochs = range(1, len(training_loss) + 1)

    # Plot Loss
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, training_loss, 'b-o', label="Training Loss")
    if validation_loss is not None:
        plt.plot(epochs, validation_loss, 'r-o', label="Validation Loss")
    plt.title("Loss Over Epochs MAPK14 model 2")
    plt.xlabel("Epochs")
    plt.ylabel("Loss (MSE)")
    plt.legend()

    #Save figure
    plt.savefig(save_path)

# Call the function with the history object
plot_metrics(history, "../results/model2_mapk14.png")
# Out:
# 9375/9375 [==============================] - 2s 222us/step - loss: 0.0777 - mean_absolute_error: 0.1514

# %%
#Save model
model.save('../models/mapk14_model_2.h5')
